# %% [markdown]
# Import Libraries:

# %%
# first neural network with keras 
#import the proper libraries
from numpy import loadtxt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %% [markdown]
# Load the Data:

# %%
#Creating a map with x: rows and input variables and y: an output variable.
#This data set is about the Pima Indians onset of diabetes. the data will be stored in a 2d-array.
#The first dimension will be rows and the second will be columns.

#load the data.
dataset = loadtxt('pima-indians-diabetes.csv', delimiter=',')

#You can split the array into two arrays by selecting subsets of columns using the standard NumPy slice operator or “:”. 
#You can select the first eight columns from index 0 to index 7 via the slice 0:8. 
#We can then select the output column (the 9th variable) via index 8.

# split into input (X) and output (y) variables
x = dataset[:,0:8]
y = dataset[:,8]

#more about array slicing and ranges: https://machinelearningmastery.com/index-slice-reshape-numpy-arrays-machine-learning-python/


#The data should now be loaded into our program.

# %% [markdown]
# Define the Keras model:

# %% [markdown]
# Models in Keras are a sequence of layers.
# We will be using a sequential model which is a group of linear stacks. And will continue to add layers until we are happy with
# our network architecture.
#
#
# When creating the first layer it's important to specicy the correct number of input features.
# In this dataset's case, 8 input variables are used so we should use the input_shape function so it will look like input_shape=(8,).
#
# Usually you can find how many layers you need from trial and error.
#
# Will be using a fully-connected network structure with three layers.
# Fully connected layers are defined using the Dense class.
# You can specify the number of neurons or nodes in the layer as the first argument and the activation function using the activation argument.
#
# will be using the rectified linear unit activation function known as ReLU for the first two layers and then use a Sigmoid function for the output layer.
# ReLU functions increase the performance of our models which is why we use them and sigmoid functions will ensure our network output will be between 0 and 1.
#
#
# To Sum it Up:
#
#     The model expects rows of data with 8 variables (the input_shape=(8,) argument).
#     The first hidden layer has 12 nodes and uses the relu activation function.
#     The second hidden layer has 8 nodes and uses the relu activation function.
#     The output layer has one node and uses the sigmoid activation function.

# %%
model = Sequential()
#first hidden layer
model.add(Dense(12, input_shape=(8,), activation='relu'))
#second hidden layer
model.add(Dense(8, activation='relu'))
#output layer
model.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# When we defined the first hidden layer, we actually were performing two actions due to the input_shape declaration.
# It defines the input/visible layer while also creating the first hidden layer.

# %% [markdown]
# Compile the Keras model:

# %% [markdown]
# We will compile the model using tensorflow. In the backend, tensorflow will take the model and use built-in numerical libraries
# and find the best way to represent the network for training based on your hardware (CPU/GPU/Distributed).
#
# When compiling, more property specifications are needed for training to set effective weights to map inputs and outputs in the dataset.
#
# The loss function must be specified. This will be used to search for optimized weights for your desired goals with the dataset. In this case, use cross entropy as the loss argument. This loss is for a binary classification problems and is defined in Keras as “binary_crossentropy“.
#
# We will define the optimizer as the efficient stochastic gradient descent algorithm “adam“. This is a popular version of gradient descent because it automatically tunes itself and gives good results in a wide range of problems.
#
# Finally, the metrics argument will be used to collect and report the classification accuracy.

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# Fit the Keras model:

# %% [markdown]
# Now that out model is compiled, we ready to run some data through it.
# With the data we've loaded, we can now call the fit() function to train our model.
#
# Training occurs over epochs, and each epoch is split into batches:
#
#     Epoch: One pass through all of the rows in the training dataset.
#     Batch: One or more samples considered by the model within an epoch before weights are updated.
#
# The model will run a fixed number of iterations over the dataset which we can define using the epochs argument.
# You must also set the number of dataset rows that are considered before the model weights are updated within each epoch, called the batch size, and set using the batch_size argument.
#
# These configurations can be changed and optimized through trial and error. You want to run it enough to where it can learn a good mapping of the rows and output data. The model will always have some error but can level out after some point. This is called model convergence

# %%
model.fit(x, y, epochs=200, batch_size=10)
#The reason is the output progress bars during training. You can easily turn these off by setting verbose=0 in the call to the fit() and evaluate() functions.
# Out:
# Epoch 1/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4318 - accuracy: 0.7891
# Epoch 2/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4309 - accuracy: 0.7995
# Epoch 3/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4201 - accuracy: 0.7930
# Epoch 4/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4262 - accuracy: 0.7943
# Epoch 5/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4245 - accuracy: 0.7995
# Epoch 6/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4166 - accuracy: 0.8047
# Epoch 7/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4265 - accuracy: 0.8008
# Epoch 8/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4221 - accuracy: 0.7943
# Epoch 9/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4176 - accuracy: 0.8034
# Epoch 10/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4177 - accuracy: 0.8021
# Epoch 11/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4198 - accuracy: 0.7982
# Epoch 12/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4372 - accuracy: 0.7852
# Epoch 13/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4243 - accuracy: 0.8047
# Epoch 14/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4362 - accuracy: 0.8008
# Epoch 15/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4269 - accuracy: 0.8008
# Epoch 16/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4259 - accuracy: 0.8021
# Epoch 17/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4189 - accuracy: 0.8021
# Epoch 18/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4351 - accuracy: 0.7865
# Epoch 19/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4286 - accuracy: 0.7917
# Epoch 20/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4238 - accuracy: 0.7982
# Epoch 21/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4287 - accuracy: 0.8008
# Epoch 22/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4195 - accuracy: 0.7930
# Epoch 23/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4250 - accuracy: 0.7930
# Epoch 24/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4221 - accuracy: 0.7943
# Epoch 25/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4191 - accuracy: 0.8034
# Epoch 26/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4234 - accuracy: 0.7982
# Epoch 27/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4241 - accuracy: 0.8047
# Epoch 28/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4241 - accuracy: 0.8008
# Epoch 29/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4222 - accuracy: 0.7878
# Epoch 30/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4189 - accuracy: 0.7956
# Epoch 31/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4192 - accuracy: 0.8047
# Epoch 32/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4228 - accuracy: 0.7943
# Epoch 33/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4336 - accuracy: 0.7956
# Epoch 34/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4250 - accuracy: 0.7982
# Epoch 35/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4318 - accuracy: 0.7852
# Epoch 36/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4212 - accuracy: 0.7917
# Epoch 37/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4127 - accuracy: 0.8060
# Epoch 38/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4160 - accuracy: 0.8164
# Epoch 39/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4213 - accuracy: 0.7943
# Epoch 40/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4213 - accuracy: 0.8034
# Epoch 41/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4284 - accuracy: 0.7839
# Epoch 42/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4310 - accuracy: 0.7930
# Epoch 43/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4573 - accuracy: 0.7891
# Epoch 44/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4271 - accuracy: 0.7917
# Epoch 45/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4201 - accuracy: 0.8151
# Epoch 46/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4205 - accuracy: 0.8060
# Epoch 47/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4163 - accuracy: 0.7943
# Epoch 48/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4157 - accuracy: 0.8034
# Epoch 49/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4173 - accuracy: 0.8073
# Epoch 50/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4243 - accuracy: 0.8060
# Epoch 51/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4153 - accuracy: 0.7982
# Epoch 52/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4124 - accuracy: 0.8099
# Epoch 53/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4200 - accuracy: 0.7891
# Epoch 54/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4281 - accuracy: 0.8021
# Epoch 55/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4123 - accuracy: 0.8060
# Epoch 56/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4161 - accuracy: 0.7969
# Epoch 57/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4215 - accuracy: 0.7969
# Epoch 58/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4196 - accuracy: 0.7904
# Epoch 59/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4078 - accuracy: 0.7956
# Epoch 60/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4271 - accuracy: 0.7865
# Epoch 61/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4209 - accuracy: 0.7904
# Epoch 62/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4193 - accuracy: 0.7982
# Epoch 63/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4396 - accuracy: 0.7786
# Epoch 64/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4237 - accuracy: 0.7930
# Epoch 65/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4160 - accuracy: 0.8047
# Epoch 66/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4187 - accuracy: 0.7969
# Epoch 67/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4198 - accuracy: 0.7995
# Epoch 68/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4291 - accuracy: 0.7904
# Epoch 69/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4218 - accuracy: 0.8008
# Epoch 70/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4287 - accuracy: 0.7982
# Epoch 71/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4164 - accuracy: 0.7982
# Epoch 72/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4164 - accuracy: 0.7969
# Epoch 73/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4255 - accuracy: 0.7904
# Epoch 74/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4166 - accuracy: 0.8034
# Epoch 75/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4205 - accuracy: 0.7969
# Epoch 76/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4143 - accuracy: 0.7995
# Epoch 77/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4204 - accuracy: 0.7956
# Epoch 78/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4151 - accuracy: 0.8008
# Epoch 79/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4153 - accuracy: 0.7995
# Epoch 80/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4220 - accuracy: 0.8021
# Epoch 81/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4254 - accuracy: 0.8008
# Epoch 82/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4138 - accuracy: 0.8060
# Epoch 83/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4213 - accuracy: 0.7995
# Epoch 84/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4176 - accuracy: 0.8008
# Epoch 85/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4140 - accuracy: 0.8099
# Epoch 86/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4171 - accuracy: 0.8073
# Epoch 87/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4684 - accuracy: 0.7969
# Epoch 88/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4312 - accuracy: 0.7995
# Epoch 89/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4228 - accuracy: 0.7917
# Epoch 90/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4167 - accuracy: 0.7982
# Epoch 91/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4175 - accuracy: 0.7969
# Epoch 92/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4196 - accuracy: 0.7930
# Epoch 93/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4149 - accuracy: 0.8021
# Epoch 94/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4192 - accuracy: 0.8112
# Epoch 95/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4231 - accuracy: 0.7969
# Epoch 96/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4165 - accuracy: 0.8021
# Epoch 97/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4160 - accuracy: 0.8021
# Epoch 98/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4212 - accuracy: 0.8008
# Epoch 99/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4147 - accuracy: 0.8008
# Epoch 100/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4130 - accuracy: 0.8034
# Epoch 101/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4159 - accuracy: 0.7982
# Epoch 102/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4167 - accuracy: 0.8021
# Epoch 103/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4102 - accuracy: 0.7956
# Epoch 104/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4151 - accuracy: 0.8034
# Epoch 105/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4093 - accuracy: 0.7982
# Epoch 106/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4161 - accuracy: 0.7969
# Epoch 107/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4312 - accuracy: 0.7982
# Epoch 108/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4179 - accuracy: 0.7956
# Epoch 109/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4123 - accuracy: 0.7956
# Epoch 110/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4197 - accuracy: 0.8060
# Epoch 111/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4165 - accuracy: 0.7995
# Epoch 112/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4120 - accuracy: 0.7943
# Epoch 113/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4143 - accuracy: 0.8008
# Epoch 114/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4173 - accuracy: 0.8021
# Epoch 115/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4158 - accuracy: 0.8073
# Epoch 116/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4101 - accuracy: 0.7917
# Epoch 117/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4224 - accuracy: 0.7982
# Epoch 118/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4256 - accuracy: 0.7891
# Epoch 119/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4184 - accuracy: 0.7943
# Epoch 120/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4167 - accuracy: 0.7943
# Epoch 121/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4286 - accuracy: 0.8021
# Epoch 122/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4199 - accuracy: 0.7969
# Epoch 123/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4220 - accuracy: 0.8034
# Epoch 124/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4191 - accuracy: 0.7956
# Epoch 125/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4227 - accuracy: 0.7982
# Epoch 126/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4235 - accuracy: 0.8008
# Epoch 127/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4113 - accuracy: 0.8060
# Epoch 128/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4211 - accuracy: 0.8060
# Epoch 129/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4181 - accuracy: 0.8021
# Epoch 130/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4216 - accuracy: 0.7969
# Epoch 131/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4287 - accuracy: 0.7982
# Epoch 132/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4269 - accuracy: 0.7982
# Epoch 133/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4232 - accuracy: 0.8034
# Epoch 134/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4132 - accuracy: 0.8008
# Epoch 135/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4228 - accuracy: 0.7904
# Epoch 136/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4193 - accuracy: 0.8034
# Epoch 137/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4091 - accuracy: 0.8034
# Epoch 138/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4172 - accuracy: 0.7995
# Epoch 139/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4166 - accuracy: 0.8047
# Epoch 140/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4121 - accuracy: 0.8008
# Epoch 141/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4196 - accuracy: 0.7943
# Epoch 142/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4216 - accuracy: 0.7826
# Epoch 143/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4094 - accuracy: 0.8034
# Epoch 144/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4118 - accuracy: 0.8060
# Epoch 145/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4103 - accuracy: 0.8073
# Epoch 146/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4098 - accuracy: 0.7995
# Epoch 147/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4150 - accuracy: 0.7982
# Epoch 148/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4148 - accuracy: 0.7891
# Epoch 149/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4119 - accuracy: 0.8008
# Epoch 150/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4290 - accuracy: 0.7943
# Epoch 151/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4165 - accuracy: 0.8034
# Epoch 152/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4195 - accuracy: 0.7904
# Epoch 153/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4232 - accuracy: 0.8008
# Epoch 154/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4213 - accuracy: 0.8021
# Epoch 155/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4314 - accuracy: 0.7943
# Epoch 156/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4204 - accuracy: 0.7995
# Epoch 157/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4347 - accuracy: 0.7969
# Epoch 158/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4101 - accuracy: 0.8008
# Epoch 159/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4138 - accuracy: 0.7943
# Epoch 160/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4200 - accuracy: 0.8021
# Epoch 161/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4086 - accuracy: 0.8047
# Epoch 162/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4199 - accuracy: 0.7930
# Epoch 163/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4236 - accuracy: 0.8008
# Epoch 164/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4224 - accuracy: 0.7995
# Epoch 165/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4168 - accuracy: 0.7969
# Epoch 166/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4326 - accuracy: 0.7956
# Epoch 167/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4133 - accuracy: 0.7904
# Epoch 168/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4140 - accuracy: 0.7956
# Epoch 169/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4148 - accuracy: 0.7865
# Epoch 170/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4240 - accuracy: 0.7852
# Epoch 171/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4138 - accuracy: 0.7982
# Epoch 172/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4115 - accuracy: 0.8060
# Epoch 173/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4223 - accuracy: 0.8021
# Epoch 174/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4236 - accuracy: 0.7943
# Epoch 175/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4158 - accuracy: 0.7969
# Epoch 176/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4194 - accuracy: 0.8021
# Epoch 177/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4163 - accuracy: 0.7995
# Epoch 178/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4079 - accuracy: 0.8138
# Epoch 179/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4076 - accuracy: 0.8008
# Epoch 180/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4064 - accuracy: 0.8034
# Epoch 181/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4282 - accuracy: 0.8034
# Epoch 182/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4122 - accuracy: 0.7995
# Epoch 183/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4165 - accuracy: 0.7982
# Epoch 184/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4186 - accuracy: 0.8008
# Epoch 185/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4244 - accuracy: 0.7917
# Epoch 186/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4167 - accuracy: 0.7982
# Epoch 187/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4113 - accuracy: 0.8034
# Epoch 188/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4160 - accuracy: 0.7943
# Epoch 189/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4159 - accuracy: 0.8008
# Epoch 190/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4115 - accuracy: 0.7969
# Epoch 191/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4240 - accuracy: 0.7930
# Epoch 192/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4260 - accuracy: 0.7891
# Epoch 193/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4104 - accuracy: 0.8008
# Epoch 194/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4140 - accuracy: 0.8060
# Epoch 195/200
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4142 - accuracy: 0.8021
# Epoch 196/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4235 - accuracy: 0.7839
# Epoch 197/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4085 - accuracy: 0.8177
# Epoch 198/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4131 - accuracy: 0.8138
# Epoch 199/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4158 - accuracy: 0.7982
# Epoch 200/200
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4134 - accuracy: 0.7930

# %% [markdown]
# This is where the work either happens on your CPU or GPU based on configuration

# %% [markdown]
# Evaluate the Keras Model:

# %% [markdown]
# We have now created a neural keras model and can evaluate its performance on the dataset.
# This will only give you an idea of how well you have modeled the dataset (e.g., train accuracy),
# but no idea of how well the algorithm might perform on new data.
# This was done for simplicity, but ideally, you could separate your data into train and test datasets for training and evaluation of your model.
#
# We can evaluate our model with the evaluate() function by passing it the same input and output used to train the model. This will generated scores based on each input and output pair.The first will be the loss of the model on the dataset, and the second will be the accuracy of the model on the dataset.

# %%
#The reason is the output progress bars during training. You can easily turn these off by setting verbose=0 in the call to the fit() and evaluate() functions;
loss, accuracy = model.evaluate(x, y)
print('Loss: %.2f' % (loss*100))
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3992 - accuracy: 0.8151
# Loss: 39.92
# Accuracy: 81.51
